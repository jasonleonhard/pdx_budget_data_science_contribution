# %%
# %matplotlib inline
import pandas as pd
fname = "../data/SS_DATA.txt"

# %%
df = pd.read_csv(fname, sep='\t', header=0)    # narray, index, columns
df
# Out:
#                org    fund program   object         col mut    mud       data  \
# 0       ATAT000001  100000       0      524   V55_TOTAL   B      0     5238.0
# 1       ATAT000001  100000       0   651532   CY_REVBUD   B      0   149494.0
# 2       ATAT000001  100000       0   642233  PY1_ACTUAL   B      0   351021.0
# 3       ATAT000001  100000       0    BUEXP   V55_TOTAL   B  AT_07   227688.0
# 4       ATAT000001  100000       0   521100  PY1_ACTUAL   B      0     2760.0
# 5       ATAT000001  100000       0   651602   CY_REVBUD   B      0    63210.0
# 6       ATAT000001  100000       0      EMS   V55_TOTAL   B  AT_05    75000.0
# 7       ATAT000001  100000       0   629011  PY1_ACTUAL   B      0   466743.0
# 8       ATAT000001  100000       0        R   V55_TOTAL   B      0     4843.0
# 9       ATAT000001  100000       0     6515  PY1_ACTUAL   B      0   355211.0
# 10      ATAT000001  100000       0      642   CY_REVBUD   B      0   240164.0
# ...

# %%
df.describe() # all except fund & data are categorical
# Out:
#                 fund          data
# count  338659.000000  3.386590e+05
# mean   346678.754960  3.917305e+05
# std    241952.676284  6.151873e+06
# min    100000.000000 -5.014369e+08
# 25%    100000.000000  2.700000e+02
# 50%    217001.000000  4.787000e+03
# 75%    601000.000000  4.371300e+04
# max    802000.000000  3.282377e+08

# %%
df.dtypes # fund is an int, data a float
# Out:
# org         object
# fund         int64
# program     object
# object      object
# col         object
# mut         object
# mud         object
# data       float64
# proj        object
# grnt        object
# dtype: object

# %%
df.count() # rows 338659
# Out:
# org        338659
# fund       338659
# program    338659
# object     338659
# col        338659
# mut        338659
# mud        338659
# data       338659
# proj       338659
# grnt       338659
# dtype: int64

# %%
len(df.columns) # 10 columns
# Out:
# 10

# %% [markdown]
# #### Now I select by column and string match for a particular organization code "ATAT000001"

# %%
ATAT000001 = df[df.org == "ATAT000001"]
# ATAT000001.head()
ATAT000001
# Out:
#             org    fund program   object         col mut    mud       data  \
# 0    ATAT000001  100000       0      524   V55_TOTAL   B      0     5238.0
# 1    ATAT000001  100000       0   651532   CY_REVBUD   B      0   149494.0
# 2    ATAT000001  100000       0   642233  PY1_ACTUAL   B      0   351021.0
# 3    ATAT000001  100000       0    BUEXP   V55_TOTAL   B  AT_07   227688.0
# 4    ATAT000001  100000       0   521100  PY1_ACTUAL   B      0     2760.0
# 5    ATAT000001  100000       0   651602   CY_REVBUD   B      0    63210.0
# 6    ATAT000001  100000       0      EMS   V55_TOTAL   B  AT_05    75000.0
# 7    ATAT000001  100000       0   629011  PY1_ACTUAL   B      0   466743.0
# 8    ATAT000001  100000       0        R   V55_TOTAL   B      0     4843.0
# 9    ATAT000001  100000       0     6515  PY1_ACTUAL   B      0   355211.0
# 10   ATAT000001  100000       0      642   CY_REVBUD   B      0   240164.0
# ...

# %%
# df.columns

# %%
# df.describe()

# %%
# e.g. 0.01
pd.set_option('display.precision', 2)

# %%
# five.describe()

# %%
df.T # Transpose rows and columns
# Out:
#              0           1           2           3           4       \
# org      ATAT000001  ATAT000001  ATAT000001  ATAT000001  ATAT000001
# fund         100000      100000      100000      100000      100000
# program           0           0           0           0           0
# object          524      651532      642233       BUEXP      521100
# col       V55_TOTAL   CY_REVBUD  PY1_ACTUAL   V55_TOTAL  PY1_ACTUAL
# mut               B           B           B           B           B
# mud               0           0           0       AT_07           0
# data        5.2e+03     1.5e+05     3.5e+05     2.3e+05     2.8e+03
# proj              0  3MFTS2AT01  7AT2WA0001  3MFFA2AT01           0
# grnt     LALS000000  LALS000000  LALS000000  LALS000000  LALS000000
#
#              5           6           7           8           9       \
# org      ATAT000001  ATAT000001  ATAT000001  ATAT000001  ATAT000001
# fund         100000      100000      100000      100000      100000
# ...
